# %% [markdown]
# <a href="https://colab.research.google.com/github/fayzullaevfarrukh98/computer_vision/blob/master/menu_detector_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Menu Decector!')
# Out:
# Menu Decector!

# %%
#-------------------
# Import Libraries
#-------------------
from google.colab import drive
import torchvision.transforms as transforms

from PIL import Image, UnidentifiedImageError
from torch.utils.data import Dataset
import os
import numpy as np

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define Dataset path
DATASET_PATH = '/content/drive/MyDrive/food101_dataset'
print('Dataset_path:', DATASET_PATH)


CUSTOM_CLASS_MAPPING = {
    "hamburger": "hamburger",
    "hot_dog": "hot_dog",
    "chocolate_cake": "dessert", # label grouping | class consolidation
    "cheesecake": "dessert",     # label grouping | class consolidation
    "kebab": "kebab",
    "pilaf": "pilaf"
}

CLASSES = ['hamburger', 'hot_dog', 'dessert', 'kebab', 'pilaf']
CLASS_TO_IDX = {cls: i for i, cls in enumerate(CLASSES)}
NUM_CLASSES = len(CLASSES)

print(NUM_CLASSES)
print(CLASS_TO_IDX)

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])
# Out:
# Dataset_path: /content/drive/MyDrive/food101_dataset
# 5
# {'hamburger': 0, 'hot_dog': 1, 'dessert': 2, 'kebab': 3, 'pilaf': 4}

# %%
# ------------------------
# Custom Dataset Class
# ------------------------

class FoodDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        print('images_length', len(self.images))
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        print('image_path', img_path)
        label = self.labels[idx]
        print('label', label)
        try:
            image = Image.open(img_path).convert('RGB')
        except (UnidentifiedImageError, OSError):
            print(f"Skipping broken image: {img_path}")
            return self.__getitem__((idx + 1) % len(self.images))
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
# ---------------------------
# Gather and Split Data
# ---------------------------

all_images = []
for original_class, mapped_class in CUSTOM_CLASS_MAPPING.items():
    class_path = os.path.join(DATASET_PATH, original_class)
    print('class_path:', class_path)
    if not os.path.exists(class_path):
        print(f"Warning: {class_path} not found")
        continue
    for img in os.listdir(class_path):
        if img.endswith(('.jpg', '.jpeg', '.png')):
            full_path = os.path.join(class_path, img)
            all_images.append((full_path, CLASS_TO_IDX[mapped_class]))

np.random.shuffle(all_images)
split = int(0.8 * len(all_images))
train_data = all_images[:split]
val_data = all_images[split:]

train_images, train_labels = zip(*train_data)
val_images, val_labels = zip(*val_data)

print('all_images:', all_images)

dataset = FoodDataset(train_images, train_labels)
print(len(dataset))
img, lbl = dataset[0]
# Out:
# class_path: /content/drive/MyDrive/food101_dataset/hamburger
# Warning: /content/drive/MyDrive/food101_dataset/hamburger not found
# class_path: /content/drive/MyDrive/food101_dataset/hot_dog
# Warning: /content/drive/MyDrive/food101_dataset/hot_dog not found
# class_path: /content/drive/MyDrive/food101_dataset/chocolate_cake
# Warning: /content/drive/MyDrive/food101_dataset/chocolate_cake not found
# class_path: /content/drive/MyDrive/food101_dataset/cheesecake
# Warning: /content/drive/MyDrive/food101_dataset/cheesecake not found
# class_path: /content/drive/MyDrive/food101_dataset/kebab
# Warning: /content/drive/MyDrive/food101_dataset/kebab not found
# class_path: /content/drive/MyDrive/food101_dataset/pilaf
# all_images: [('/content/drive/MyDrive/food101_dataset/pilaf/Image_56.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_39.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_48.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_32.jpeg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_62.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_26.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_83.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_72.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_16.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_94.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_75.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_23.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_82.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_37.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_36.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_11.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_63.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_74.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_29.jpeg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_47.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_86.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_53.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_42.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_4.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_24.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_27.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_61.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_70.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_89.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_9.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_60.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_79.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_55.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_98.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_76.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_99.jpeg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_51.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_2.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_18.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_1.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_30.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_87.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_7.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_14.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_68.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_52.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_58.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_21.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_100.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_38.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_54.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_78.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_25.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_40.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_19.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_44.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_20.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_77.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_8.jpg', 4), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_66.jpg', 4), ('/content/drive/MyDrive/food ...
# images_length 76
# 76
# image_path /content/drive/MyDrive/food101_dataset/pilaf/Image_56.jpg
# label 4
